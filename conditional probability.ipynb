# %%
import os
import os.path

path = 'C:\\Users\\ret' 
os.chdir(path)
sp=[]
sp1=[]
count={}
count_all_words_sp=0
for w in open('sports_corpus_2.txt').read().split():
    count_all_words_sp+=1
    if w in count:
        count[w]+=1
    else:
        count[w]=1

for word,times in count.items():
    sp.append(word)
    sp1.append(times)
#print(sp)   
#sum1=0
#for i in range(0,len(sp1)):
 #   sum1 = sum1 + int(sp1[i])
#print('%d' %(sum1))

en=[]
en1=[]
count={}
count_all_words_en=0
for w in open('entertainment_corpus_2.txt').read().split():
    count_all_words_en+=1
    if w in count:
        count[w]+=1
    else:
        count[w]=1

for word,times in count.items():
    en.append(word)
    en1.append(times)
    
bi=[]
bi1=[]
count={}
count_all_words_bi=0
for w in open('business_corpus_2.txt').read().split():
    count_all_words_bi+=1
    if w in count:
        count[w]+=1
    else:
        count[w]=1

for word,times in count.items():
    bi.append(word)
    bi1.append(times)
    
po=[]
po1=[]
count={}
count_all_words_po=0
for w in open('politics_corpus_2.txt').read().split():
    count_all_words_po+=1
    if w in count:
        count[w]+=1
    else:
        count[w]=1

for word,times in count.items():
    po.append(word)
    po1.append(times)
    
te=[]
te1=[]
count={}
count_all_words_te=0
for w in open('technology_corpus_2.txt').read().split():
    count_all_words_te+=1
    if w in count:
        count[w]+=1
    else:
        count[w]=1

for word,times in count.items():
    te.append(word)
    te1.append(times)
    
len_sp=len(sp1)
len_en=len(en1)
len_bi=len(bi1)
len_po=len(po1)
len_te=len(te1)
    
#print('%d %d %d %d %d' %(len_sp,len_en,len_bi,len_po,len_te))

p_i_sp=[]
for i in range(0,len_sp):
    p_i_sp.append(float(sp1[i]+1) / (count_all_words_sp + (len_sp+len_en+len_bi+len_po+len_te)))
    
with open('Conditnal_probabilities_sport_2.txt','w') as f:
      for i in range(0,len_sp):
            f.write('%s %.20f;\n' %(sp[i],p_i_sp[i]))
            print ("%s %.20f", (sp[i],p_i_sp[i]) )
            
arr3 = []
arr4 = []

MyFile=open('weightmatrix_sp_2.txt','r')
total_count=0

for x in MyFile.read().split(';'):
    for y in x.split():
        if(total_count%2==0):
            narr = [y]
            arr3 = arr3 + narr
        else:
            narr2 = [y]
            arr4 = arr4 + narr2
            
        total_count = total_count+1;
        
#print("\n\nweight sports\n")       
for i in range(0,len(sp)):
    for j in range(0,len(arr3)):
        if(sp[i]==arr3[j]):
            p_i_sp[i]+= float(arr4[j])

    
with open('Conditnal_probabilities_sport_2_wm.txt','w') as f:
      for i in range(0,len_sp):
            f.write('%s %.20f;\n' %(sp[i],p_i_sp[i]))
            print ("%s %.20f", (sp[i],p_i_sp[i]) )
    
#print("\n\n environment\n")    
p_i_en=[]
for i in range(0,len_en):
    p_i_en.append(float(en1[i]+1) / (count_all_words_en + (len_sp+len_en+len_bi+len_po+len_te)))
    
with open('Conditnal_probabilities_entertainment_2.txt','w') as f:
      for i in range(0,len_en):
            f.write('%s %.20f;\n' %(en[i],p_i_en[i]))
            #print ("%s %.20f", (en[i],p_i_en[i]) )
            
            
arr3 = []
arr4 = []

MyFile=open('weightmatrix_e_2.txt','r')
total_count=0

for x in MyFile.read().split(';'):
    for y in x.split():
        if(total_count%2==0):
            narr = [y]
            arr3 = arr3 + narr
        else:
            narr2 = [y]
            arr4 = arr4 + narr2
            
        total_count = total_count+1;
        
#print("\n\nweight environment\n")       
for i in range(0,len(en)):
    for j in range(0,len(arr3)):
        if(en[i]==arr3[j]):
            p_i_en[i]+= float(arr4[j])

    
with open('Conditnal_probabilities_entertainment_2_wm.txt','w') as f:
      for i in range(0,len_en):
            f.write('%s %.20f;\n' %(en[i],p_i_en[i]))
            #print ("%s %.20f", (en[i],p_i_en[i]) )

#print("\n\n business\n") 
p_i_bi=[]
for i in range(0,len_bi):
    p_i_bi.append(float(bi1[i]+1) / (count_all_words_bi + (len_sp+len_en+len_bi+len_po+len_te)))
    
with open('Conditnal_probabilities_bussiness_2.txt','w') as f:
      for i in range(0,len_bi):
            f.write('%s %.20f;\n' %(bi[i],p_i_bi[i]))
            #print ("%s %.20f", (bi[i],p_i_bi[i]) )
    
arr3 = []
arr4 = []

MyFile=open('weightmatrix_b_2.txt','r')
total_count=0

for x in MyFile.read().split(';'):
    for y in x.split():
        if(total_count%2==0):
            narr = [y]
            arr3 = arr3 + narr
        else:
            narr2 = [y]
            arr4 = arr4 + narr2
            
        total_count = total_count+1;
        
#print("\n\nweight business\n")       
for i in range(0,len(bi)):
    for j in range(0,len(arr3)):
        if(bi[i]==arr3[j]):
            p_i_bi[i]+= float(arr4[j])

    
with open('Conditnal_probabilities_bussiness_2_wm.txt','w') as f:
      for i in range(0,len_bi):
            f.write('%s %.20f;\n' %(bi[i],p_i_bi[i]))
            #print ("%s %.20f", (bi[i],p_i_bi[i]) )

#print("\n\npolitics\n")
p_i_po=[]
for i in range(0,len_po):
    p_i_po.append(float(po1[i]+1) / (count_all_words_po + (len_sp+len_en+len_bi+len_po+len_te)))
    
with open('Conditnal_probabilities_politics_2.txt','w') as f:
      for i in range(0,len_po):
            f.write('%s %.20f;\n' %(po[i],p_i_po[i]))
            #print ("%s %.20f", (po[i],p_i_po[i]) )
            
arr3 = []
arr4 = []

MyFile=open('weightmatrix_p_2.txt','r')
total_count=0

for x in MyFile.read().split(';'):
    for y in x.split():
        if(total_count%2==0):
            narr = [y]
            arr3 = arr3 + narr
        else:
            narr2 = [y]
            arr4 = arr4 + narr2
            
        total_count = total_count+1;
        
#print("\n\nweight politics\n")       
for i in range(0,len(po)):
    for j in range(0,len(arr3)):
        if(po[i]==arr3[j]):
            p_i_po[i]+= float(arr4[j])

    
with open('Conditnal_probabilities_politics_2_wm.txt','w') as f:
      for i in range(0,len_po):
            f.write('%s %.20f;\n' %(po[i],p_i_po[i]))
            #print ("%s %.20f", (po[i],p_i_po[i]) )

#print("\n\ntechnology\n") 
p_i_te=[]
for i in range(0,len_te):
    p_i_te.append(float(te1[i]+1) / (count_all_words_te + (len_sp+len_en+len_bi+len_po+len_te)))
    
with open('Conditnal_probabilities_technology_2.txt','w') as f:
      for i in range(0,len_te):
            f.write('%s %.20f;\n' %(te[i],p_i_te[i]))
            #print ("%s %.20f", (te[i],p_i_te[i])) 
            
            
arr3 = []
arr4 = []

MyFile=open('weightmatrix_t_2.txt','r')
total_count=0

for x in MyFile.read().split(';'):
    for y in x.split():
        if(total_count%2==0):
            narr = [y]
            arr3 = arr3 + narr
        else:
            narr2 = [y]
            arr4 = arr4 + narr2
            
        total_count = total_count+1;
        
#print("\n\nweight technology\n")       
for i in range(0,len(te)):
    for j in range(0,len(arr3)):
        if(te[i]==arr3[j]):
            p_i_te[i]+= float(arr4[j])

    
with open('Conditnal_probabilities_technology_2_wm.txt','w') as f:
      for i in range(0,len_te):
            f.write('%s %.20f;\n' %(te[i],p_i_te[i]))
            #print ("%s %.20f", (te[i],p_i_te[i]) )
# Out:
# %s %.20f ('medallist', 0.00038498556304138594)
# %s %.20f ('challeng', 0.0007699711260827719)
# %s %.20f ('parti', 0.00038498556304138594)
# %s %.20f ('hungri', 0.00038498556304138594)
# %s %.20f ('assist', 0.00038498556304138594)
# %s %.20f ('hellen', 0.0005774783445620789)
# %s %.20f ('contest', 0.00038498556304138594)
# %s %.20f ('talk', 0.00038498556304138594)
# %s %.20f ('attent', 0.0005774783445620789)
# %s %.20f ('feign', 0.00038498556304138594)
# %s %.20f ('region', 0.00038498556304138594)
# %s %.20f ('retir', 0.00038498556304138594)
# %s %.20f ('half', 0.00038498556304138594)
# %s %.20f ('everi', 0.00038498556304138594)
# %s %.20f ('event', 0.001347449470644851)
# %s %.20f ('gruell', 0.00038498556304138594)
# %s %.20f ('manageri', 0.00038498556304138594)
# %s %.20f ('confirm', 0.00038498556304138594)
# %s %.20f ('fernando', 0.0005774783445620789)
# %s %.20f ('piec', 0.00038498556304138594)
# %s %.20f ('but', 0.002694898941289702)
# %s %.20f ('led', 0.00038498556304138594)
# ...

# %%
import os
import os.path

path = 'C:\\Users\\ret' 
os.chdir(path)
sp=[]
sp1=[]
count={}
count_all_words_sp=0
for w in open('sports_corpus_1.txt').read().split():
    count_all_words_sp+=1
    if w in count:
        count[w]+=1
    else:
        count[w]=1

for word,times in count.items():
    sp.append(word)
    sp1.append(times)
#print(sp)   
#sum1=0
#for i in range(0,len(sp1)):
 #   sum1 = sum1 + int(sp1[i])
#print('%d' %(sum1))

en=[]
en1=[]
count={}
count_all_words_en=0
for w in open('entertainment_corpus_1.txt').read().split():
    count_all_words_en+=1
    if w in count:
        count[w]+=1
    else:
        count[w]=1

for word,times in count.items():
    en.append(word)
    en1.append(times)
    
bi=[]
bi1=[]
count={}
count_all_words_bi=0
for w in open('business_corpus_1.txt').read().split():
    count_all_words_bi+=1
    if w in count:
        count[w]+=1
    else:
        count[w]=1

for word,times in count.items():
    bi.append(word)
    bi1.append(times)
    
po=[]
po1=[]
count={}
count_all_words_po=0
for w in open('politics_corpus_1.txt').read().split():
    count_all_words_po+=1
    if w in count:
        count[w]+=1
    else:
        count[w]=1

for word,times in count.items():
    po.append(word)
    po1.append(times)
    
te=[]
te1=[]
count={}
count_all_words_te=0
for w in open('technology_corpus_1.txt').read().split():
    count_all_words_te+=1
    if w in count:
        count[w]+=1
    else:
        count[w]=1

for word,times in count.items():
    te.append(word)
    te1.append(times)
    
len_sp=len(sp1)
len_en=len(en1)
len_bi=len(bi1)
len_po=len(po1)
len_te=len(te1)
    
#print('%d %d %d %d %d' %(len_sp,len_en,len_bi,len_po,len_te))

p_i_sp=[]
for i in range(0,len_sp):
    p_i_sp.append(float(sp1[i]+1) / (count_all_words_sp + (len_sp+len_en+len_bi+len_po+len_te)))
    
with open('Conditnal_probabilities_sport_1.txt','w') as f:
      for i in range(0,len_sp):
            f.write('%s %.20f;\n' %(sp[i],p_i_sp[i]))
            print ("%s %.20f", (sp[i],p_i_sp[i]) )
            
arr3 = []
arr4 = []

MyFile=open('weightmatrix_sp_.txt','r')
total_count=0

for x in MyFile.read().split(';'):
    for y in x.split():
        if(total_count%2==0):
            narr = [y]
            arr3 = arr3 + narr
        else:
            narr2 = [y]
            arr4 = arr4 + narr2
            
        total_count = total_count+1;
        
#print("\n\nweight sports\n")       
for i in range(0,len(sp)):
    for j in range(0,len(arr3)):
        if(sp[i]==arr3[j]):
            p_i_sp[i]+= float(arr4[j])

    
with open('Conditnal_probabilities_sport_1_wm.txt','w') as f:
      for i in range(0,len_sp):
            f.write('%s %.20f;\n' %(sp[i],p_i_sp[i]))
            print ("%s %.20f", (sp[i],p_i_sp[i]) )
    
#print("\n\n environment\n")    
p_i_en=[]
for i in range(0,len_en):
    p_i_en.append(float(en1[i]+1) / (count_all_words_en + (len_sp+len_en+len_bi+len_po+len_te)))
    
with open('Conditnal_probabilities_entertainment_1.txt','w') as f:
      for i in range(0,len_en):
            f.write('%s %.20f;\n' %(en[i],p_i_en[i]))
            #print ("%s %.20f", (en[i],p_i_en[i]) )
            
            
arr3 = []
arr4 = []

MyFile=open('weightmatrix_e_.txt','r')
total_count=0

for x in MyFile.read().split(';'):
    for y in x.split():
        if(total_count%2==0):
            narr = [y]
            arr3 = arr3 + narr
        else:
            narr2 = [y]
            arr4 = arr4 + narr2
            
        total_count = total_count+1;
        
#print("\n\nweight environment\n")       
for i in range(0,len(en)):
    for j in range(0,len(arr3)):
        if(en[i]==arr3[j]):
            p_i_en[i]+= float(arr4[j])

    
with open('Conditnal_probabilities_entertainment_1_wm.txt','w') as f:
      for i in range(0,len_en):
            f.write('%s %.20f;\n' %(en[i],p_i_en[i]))
            #print ("%s %.20f", (en[i],p_i_en[i]) )

#print("\n\n business\n") 
p_i_bi=[]
for i in range(0,len_bi):
    p_i_bi.append(float(bi1[i]+1) / (count_all_words_bi + (len_sp+len_en+len_bi+len_po+len_te)))
    
with open('Conditnal_probabilities_bussiness_1.txt','w') as f:
      for i in range(0,len_bi):
            f.write('%s %.20f;\n' %(bi[i],p_i_bi[i]))
            #print ("%s %.20f", (bi[i],p_i_bi[i]) )
    
arr3 = []
arr4 = []

MyFile=open('weightmatrix_b_.txt','r')
total_count=0

for x in MyFile.read().split(';'):
    for y in x.split():
        if(total_count%2==0):
            narr = [y]
            arr3 = arr3 + narr
        else:
            narr2 = [y]
            arr4 = arr4 + narr2
            
        total_count = total_count+1;
        
#print("\n\nweight business\n")       
for i in range(0,len(bi)):
    for j in range(0,len(arr3)):
        if(bi[i]==arr3[j]):
            p_i_bi[i]+= float(arr4[j])

    
with open('Conditnal_probabilities_bussiness_1_wm.txt','w') as f:
      for i in range(0,len_bi):
            f.write('%s %.20f;\n' %(bi[i],p_i_bi[i]))
            #print ("%s %.20f", (bi[i],p_i_bi[i]) )

#print("\n\npolitics\n")
p_i_po=[]
for i in range(0,len_po):
    p_i_po.append(float(po1[i]+1) / (count_all_words_po + (len_sp+len_en+len_bi+len_po+len_te)))
    
with open('Conditnal_probabilities_politics_1.txt','w') as f:
      for i in range(0,len_po):
            f.write('%s %.20f;\n' %(po[i],p_i_po[i]))
            #print ("%s %.20f", (po[i],p_i_po[i]) )
            
arr3 = []
arr4 = []

MyFile=open('weightmatrix_p_.txt','r')
total_count=0

for x in MyFile.read().split(';'):
    for y in x.split():
        if(total_count%2==0):
            narr = [y]
            arr3 = arr3 + narr
        else:
            narr2 = [y]
            arr4 = arr4 + narr2
            
        total_count = total_count+1;
        
#print("\n\nweight politics\n")       
for i in range(0,len(po)):
    for j in range(0,len(arr3)):
        if(po[i]==arr3[j]):
            p_i_po[i]+= float(arr4[j])

    
with open('Conditnal_probabilities_politics_1_wm.txt','w') as f:
      for i in range(0,len_po):
            f.write('%s %.20f;\n' %(po[i],p_i_po[i]))
            #print ("%s %.20f", (po[i],p_i_po[i]) )

#print("\n\ntechnology\n") 
p_i_te=[]
for i in range(0,len_te):
    p_i_te.append(float(te1[i]+1) / (count_all_words_te + (len_sp+len_en+len_bi+len_po+len_te)))
    
with open('Conditnal_probabilities_technology_1.txt','w') as f:
      for i in range(0,len_te):
            f.write('%s %.20f;\n' %(te[i],p_i_te[i]))
            #print ("%s %.20f", (te[i],p_i_te[i])) 
            
            
arr3 = []
arr4 = []

MyFile=open('weightmatrix_t_.txt','r')
total_count=0

for x in MyFile.read().split(';'):
    for y in x.split():
        if(total_count%2==0):
            narr = [y]
            arr3 = arr3 + narr
        else:
            narr2 = [y]
            arr4 = arr4 + narr2
            
        total_count = total_count+1;
        
#print("\n\nweight technology\n")       
for i in range(0,len(te)):
    for j in range(0,len(arr3)):
        if(te[i]==arr3[j]):
            p_i_te[i]+= float(arr4[j])

    
with open('Conditnal_probabilities_technology_1_wm.txt','w') as f:
      for i in range(0,len_te):
            f.write('%s %.20f;\n' %(te[i],p_i_te[i]))
            #print ("%s %.20f", (te[i],p_i_te[i]) )
# Out:
# %s %.20f ('medallist', 0.0010375596596804316)
# %s %.20f ('main', 0.0004150238638721727)
# %s %.20f ('contest', 0.0006225357958082589)
# %s %.20f ('attent', 0.0004150238638721727)
# %s %.20f ('then', 0.0004150238638721727)
# %s %.20f ('leap', 0.0006225357958082589)
# %s %.20f ('easili', 0.0004150238638721727)
# %s %.20f ('event', 0.0006225357958082589)
# %s %.20f ('tripl', 0.0008300477277443454)
# %s %.20f ('ashia', 0.0004150238638721727)
# %s %.20f ('ato', 0.0004150238638721727)
# %s %.20f ('april', 0.0008300477277443454)
# %s %.20f ('but', 0.0008300477277443454)
# %s %.20f ('specialist', 0.0004150238638721727)
# %s %.20f ('fastest', 0.0004150238638721727)
# %s %.20f ('may', 0.0006225357958082589)
# %s %.20f ('struggl', 0.0004150238638721727)
# %s %.20f ('100m', 0.0014525835235526042)
# %s %.20f ('came', 0.0008300477277443454)
# %s %.20f ('fifth', 0.0004150238638721727)
# %s %.20f ('ian', 0.0004150238638721727)
# %s %.20f ('els', 0.0004150238638721727)
# ...
