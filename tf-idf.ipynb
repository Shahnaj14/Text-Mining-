# %%
import math
from math import *

    
a=[]
a1=[]
count_all_words=0 #count all words in the original cls
count={}
for w in open('sports_corpus_2.txt').read().split():
            count_all_words+=1
            if w in count:
                count[w]+=1
            else:
                count[w]=1
for word,times in count.items():
    a.append(word)
    a1.append(times) 
    

tf_sp=[]
for x in range(0,len(a)):
    tf_sp.append((a1[x]/count_all_words))

b=[]
b1=[]
count_all_words2=0
count={}
for w in open('business_corpus_2.txt').read().split():
            count_all_words2+=1
            if w in count:
                count[w]+=1
            else:
                count[w]=1
for word,times in count.items():
    b.append(word)
    b1.append(times)
    
tf_b=[]
for x in range(0,len(b)):
    tf_b.append((b1[x]/count_all_words2))
     
c=[]
c1=[]
count_all_words3=0
count={}
for w in open('entertainment_corpus_2.txt').read().split():
            count_all_words3+=1
            if w in count:
                count[w]+=1
            else:
                count[w]=1

for word,times in count.items():
    c.append(word)
    c1.append(times)
    
tf_e=[]
for x in range(0,len(c)):
    tf_e.append((c1[x]/count_all_words3))

d=[]
d1=[]
count_all_words4=0
count={}
for w in open('politics_corpus_2.txt').read().split():
            count_all_words4+=1
            if w in count:
                count[w]+=1
            else:
                count[w]=1
for word,times in count.items():
    d.append(word)
    d1.append(times)
    
tf_p=[]
for x in range(0,len(d)):
    tf_p.append((d1[x]/count_all_words4))
    
e=[]
e1=[]
count_all_words5=0
count={}
for w in open('technology_corpus_2.txt').read().split():
            count_all_words5+=1
            if w in count:
                count[w]+=1
            else:
                count[w]=1
for word,times in count.items():
    e.append(word)
    e1.append(times)
    
tf_t=[]
for x in range(0,len(e)):
    tf_t.append((e1[x]/count_all_words5))
    
lna1=len(a1) 
lnb1=len(b1)
lnc1=len(c1)
lnd1=len(d1)
lne1=len(e1)
idf=[]  
print ("idf_sports\n")
print (count_all_words)
for x in range(0,lna1):
    cn=0
    for y in range(0,lnb1):
        if(a[x]==b[y]):
            cn+=1
    for y in range(0,lnc1):
        if(a[x]==c[y]):
            cn+=1  
    for y in range(0,lnd1):
        if(a[x]==d[y]):
            cn+=1
    for y in range(0,lne1):
        if(a[x]==e[y]):
            cn+=1
    #print ("cn=%d", cn)
    if(cn==0):
        idf.append(log(5/(cn+1.0)))
    else:
        idf.append(log(5/(cn)))
    print ('%s %d tf=%f cn=%d idf=%f' %(a[x],a1[x],tf_sp[x],cn,idf[x]))
            

weight=[]
for x in range(0,len(a)):
    weight.append(tf_sp[x]*idf[x])

with open('weightmatrix_sp_2.txt','w') as f:
      for i in range(0,len(a)):
            f.write('%s %.20f;\n' %(a[i],weight[i]))
idf_b=[]           
print ("idf_business\n")
print (count_all_words2)
for x in range(0,lnb1):
    cn=0
    for y in range(0,lna1):
        if(b[x]==a[y]):
            cn+=1
    for y in range(0,lnc1):
        if(b[x]==c[y]):
            cn+=1  
    for y in range(0,lnd1):
        if(b[x]==d[y]):
            cn+=1
    for y in range(0,lne1):
        if(b[x]==e[y]):
            cn+=1
    if(cn==0):
        idf_b.append(log(5/(cn+1.0)))
    else:
        idf_b.append(log(5/(cn)))
    print ('%s %d tf=%f cn=%d idf_b=%f' %(b[x],b1[x],tf_b[x],cn,idf_b[x]))
            
weight=[]
for x in range(0,len(b)):
    weight.append(tf_b[x]*idf_b[x])

with open('weightmatrix_b_2.txt','w') as f:
      for i in range(0,len(b)):
            f.write('%s %.20f;\n' %(b[i],weight[i]))
            
print ("idf_entertainment\n")
print (count_all_words3)
idf_e=[]           
for x in range(0,lnc1):
    cn=0
    for y in range(0,lna1):
        if(c[x]==a[y]):
            cn+=1
    for y in range(0,lnb1):
        if(c[x]==b[y]):
            cn+=1  
    for y in range(0,lnd1):
        if(c[x]==d[y]):
            cn+=1
    for y in range(0,lne1):
        if(c[x]==e[y]):
            cn+=1
    if(cn==0):
        idf_e.append(log(5/(cn+1.0)))
    else:
        idf_e.append(log(5/(cn)))
    print ('%s %d tf=%f cn=%d idf_e=%f' %(c[x],c1[x],tf_e[x],cn,idf_e[x]))
            
weight=[]
for x in range(0,len(c)):
    weight.append(tf_e[x]*idf_e[x])

with open('weightmatrix_e_2.txt','w') as f:
      for i in range(0,len(c)):
            f.write('%s %.20f;\n' %(c[i],weight[i]))
            
print ("idf_politics\n")
print (count_all_words4)
idf_p=[]           
for x in range(0,lnd1):
    cn=0
    for y in range(0,lna1):
        if(d[x]==a[y]):
            cn+=1
    for y in range(0,lnb1):
        if(d[x]==b[y]):
            cn+=1  
    for y in range(0,lnc1):
        if(d[x]==c[y]):
            cn+=1
    for y in range(0,lne1):
        if(d[x]==e[y]):
            cn+=1
    if(cn==0):
        idf_p.append(log(5/(cn+1.0)))
    else:
        idf_p.append(log(5/(cn)))
    print ('%s %d tf=%f cn=%d idf_p=%f' %(d[x],d1[x],tf_p[x],cn,idf_p[x]))
            
weight=[]
for x in range(0,len(d)):
    weight.append(tf_p[x]*idf_p[x])

with open('weightmatrix_p_2.txt','w') as f:
      for i in range(0,len(d)):
            f.write('%s %.20f;\n' %(d[i],weight[i]))
print(weight)            
print ("idf_technology\n")
print (count_all_words5)
idf_t=[]           
for x in range(0,lne1):
    cn=0
    for y in range(0,lna1):
        if(e[x]==a[y]):
            cn+=1
    for y in range(0,lnb1):
        if(e[x]==b[y]):
            cn+=1  
    for y in range(0,lnc1):
        if(e[x]==c[y]):
            cn+=1
    for y in range(0,lnd1):
        if(e[x]==d[y]):
            cn+=1
    if(cn==0):
        idf_t.append(log(5/(cn+1.0)))
    else:
        idf_t.append(log(5/(cn)))
    print ('%s %d tf=%f cn=%d idf_t=%f' %(e[x],e1[x],tf_t[x],cn,idf_t[x]))
            
weight=[]
for x in range(0,len(e)):
    #s= math.sqrt(pow(float(tf_t[x]*idf_t[x]),2))
    weight.append((tf_t[x]*idf_t[x]))

with open('weightmatrix_t_2.txt','w') as f:
      for i in range(0,len(e)):
            f.write('%s %.20f;\n' %(e[i],weight[i]))

print (weight)
# Out:
# idf_sports
#
# 1240
# indict 1 tf=0.000806 cn=0 idf=1.609438
# applic 1 tf=0.000806 cn=1 idf=1.609438
# somebodi 2 tf=0.001613 cn=1 idf=1.609438
# chief 2 tf=0.001613 cn=4 idf=0.223144
# teeth 1 tf=0.000806 cn=0 idf=1.609438
# bow 1 tf=0.000806 cn=0 idf=1.609438
# chanc 1 tf=0.000806 cn=1 idf=1.609438
# earlier 4 tf=0.003226 cn=3 idf=0.510826
# past 1 tf=0.000806 cn=2 idf=0.916291
# unsubstanti 1 tf=0.000806 cn=0 idf=1.609438
# snap 1 tf=0.000806 cn=0 idf=1.609438
# despit 1 tf=0.000806 cn=3 idf=0.510826
# previous 2 tf=0.001613 cn=0 idf=1.609438
# score 1 tf=0.000806 cn=0 idf=1.609438
# battl 1 tf=0.000806 cn=2 idf=0.916291
# reportedli 1 tf=0.000806 cn=1 idf=1.609438
# ambit 1 tf=0.000806 cn=1 idf=1.609438
# reiter 1 tf=0.000806 cn=1 idf=1.609438
# eve 1 tf=0.000806 cn=1 idf=1.609438
# pound 2 tf=0.001613 cn=0 idf=1.609438
# global 1 tf=0.000806 cn=2 idf=0.916291
# goal 1 tf=0.000806 cn=1 idf=1.609438
# also 13 tf=0.010484 cn=4 idf=0.223144
# medal 3 tf=0.002419 cn=1 idf=1.609438
# ...

# %%
from math import *
MyFile=open('sports_corpus_1.txt','r')
    
a=[]
a1=[]
count_all_words=0 #count all words in the original cls
count={}
for w in open('sports_corpus_1.txt').read().split():
            count_all_words+=1
            if w in count:
                count[w]+=1
            else:
                count[w]=1
for word,times in count.items():
    a.append(word)
    a1.append(times) 
    

tf_sp=[]
for x in range(0,len(a)):
    tf_sp.append((a1[x]/count_all_words))

b=[]
b1=[]
count_all_words2=0
count={}
for w in open('business_corpus_1.txt').read().split():
            count_all_words2+=1
            if w in count:
                count[w]+=1
            else:
                count[w]=1
for word,times in count.items():
    b.append(word)
    b1.append(times)
    
tf_b=[]
for x in range(0,len(b)):
    tf_b.append((b1[x]/count_all_words2))
     
c=[]
c1=[]
count_all_words3=0
count={}
for w in open('entertainment_corpus_1.txt').read().split():
            count_all_words3+=1
            if w in count:
                count[w]+=1
            else:
                count[w]=1

for word,times in count.items():
    c.append(word)
    c1.append(times)
    
tf_e=[]
for x in range(0,len(c)):
    tf_e.append((c1[x]/count_all_words3))

d=[]
d1=[]
count_all_words4=0
count={}
for w in open('politics_corpus_1.txt').read().split():
            count_all_words4+=1
            if w in count:
                count[w]+=1
            else:
                count[w]=1
for word,times in count.items():
    d.append(word)
    d1.append(times)
    
tf_p=[]
for x in range(0,len(d)):
    tf_p.append((d1[x]/count_all_words4))
    
e=[]
e1=[]
count_all_words5=0
count={}
for w in open('technology_corpus_1.txt').read().split():
            count_all_words5+=1
            if w in count:
                count[w]+=1
            else:
                count[w]=1
for word,times in count.items():
    e.append(word)
    e1.append(times)
    
tf_t=[]
for x in range(0,len(e)):
    tf_t.append((e1[x]/count_all_words5))
    
lna1=len(a1) 
lnb1=len(b1)
lnc1=len(c1)
lnd1=len(d1)
lne1=len(e1)
idf=[]  
print ("idf_sports\n")
print (count_all_words)
for x in range(0,lna1):
    cn=0
    for y in range(0,lnb1):
        if(a[x]==b[y]):
            cn+=1
    for y in range(0,lnc1):
        if(a[x]==c[y]):
            cn+=1  
    for y in range(0,lnd1):
        if(a[x]==d[y]):
            cn+=1
    for y in range(0,lne1):
        if(a[x]==e[y]):
            cn+=1
    #print ("cn=%d", cn)
    if(cn==0):
        idf.append(log(5/(cn+1.0)))
    else:
        idf.append(log(5/(cn)))
    print ('%s %d tf=%f cn=%d idf=%f' %(a[x],a1[x],tf_sp[x],cn,idf[x]))
            

weight=[]
for x in range(0,len(a)):
    weight.append(tf_sp[x]*idf[x])

with open('weightmatrix_sp_.txt','w') as f:
      for i in range(0,len(a)):
            f.write('%s %.20f;\n' %(a[i],weight[i]))
idf_b=[]           
print ("idf_business\n")
print (count_all_words2)
for x in range(0,lnb1):
    cn=0
    for y in range(0,lna1):
        if(b[x]==a[y]):
            cn+=1
    for y in range(0,lnc1):
        if(b[x]==c[y]):
            cn+=1  
    for y in range(0,lnd1):
        if(b[x]==d[y]):
            cn+=1
    for y in range(0,lne1):
        if(b[x]==e[y]):
            cn+=1
    if(cn==0):
        idf_b.append(log(5/(cn+1.0)))
    else:
        idf_b.append(log(5/(cn)))
    print ('%s %d tf=%f cn=%d idf_b=%f' %(b[x],b1[x],tf_b[x],cn,idf_b[x]))
            
weight=[]
for x in range(0,len(b)):
    weight.append(tf_b[x]*idf_b[x])

with open('weightmatrix_b_.txt','w') as f:
      for i in range(0,len(b)):
            f.write('%s %.20f;\n' %(b[i],weight[i]))
            
print ("idf_entertainment\n")
print (count_all_words3)
idf_e=[]           
for x in range(0,lnc1):
    cn=0
    for y in range(0,lna1):
        if(c[x]==a[y]):
            cn+=1
    for y in range(0,lnb1):
        if(c[x]==b[y]):
            cn+=1  
    for y in range(0,lnd1):
        if(c[x]==d[y]):
            cn+=1
    for y in range(0,lne1):
        if(c[x]==e[y]):
            cn+=1
    if(cn==0):
        idf_e.append(log(5/(cn+1.0)))
    else:
        idf_e.append(log(5/(cn)))
    print ('%s %d tf=%f cn=%d idf_e=%f' %(c[x],c1[x],tf_e[x],cn,idf_e[x]))
            
weight=[]
for x in range(0,len(c)):
    weight.append(tf_e[x]*idf_e[x])

with open('weightmatrix_e_.txt','w') as f:
      for i in range(0,len(c)):
            f.write('%s %.20f;\n' %(c[i],weight[i]))
            
print ("idf_politics\n")
print (count_all_words4)
idf_p=[]           
for x in range(0,lnd1):
    cn=0
    for y in range(0,lna1):
        if(d[x]==a[y]):
            cn+=1
    for y in range(0,lnb1):
        if(d[x]==b[y]):
            cn+=1  
    for y in range(0,lnc1):
        if(d[x]==c[y]):
            cn+=1
    for y in range(0,lne1):
        if(d[x]==e[y]):
            cn+=1
    if(cn==0):
        idf_p.append(log(5/(cn+1.0)))
    else:
        idf_p.append(log(5/(cn)))
    print ('%s %d tf=%f cn=%d idf_p=%f' %(d[x],d1[x],tf_p[x],cn,idf_p[x]))
            
weight=[]
for x in range(0,len(d)):
    weight.append(tf_p[x]*idf_p[x])

with open('weightmatrix_p_.txt','w') as f:
      for i in range(0,len(d)):
            f.write('%s %.20f;\n' %(d[i],weight[i]))
            
print ("idf_technology\n")
print (count_all_words5)
idf_t=[]           
for x in range(0,lne1):
    cn=0
    for y in range(0,lna1):
        if(e[x]==a[y]):
            cn+=1
    for y in range(0,lnb1):
        if(e[x]==b[y]):
            cn+=1  
    for y in range(0,lnc1):
        if(e[x]==c[y]):
            cn+=1
    for y in range(0,lnd1):
        if(e[x]==d[y]):
            cn+=1
    if(cn==0):
        idf_t.append(log(5/(cn+1.0)))
    else:
        idf_t.append(log(5/(cn)))
    print ('%s %d tf=%f cn=%d idf_t=%f' %(e[x],e1[x],tf_t[x],cn,idf_t[x]))
            
weight=[]
for x in range(0,len(e)):
    weight.append(tf_t[x]*idf_t[x])

with open('weightmatrix_t_.txt','w') as f:
      for i in range(0,len(e)):
            f.write('%s %.20f;\n' %(e[i],weight[i]))

print (weight)
print(1)
# Out:
# idf_sports
#
# 1026
# russian 1 tf=0.000975 cn=1 idf=1.609438
# underestim 1 tf=0.000975 cn=0 idf=1.609438
# jump 6 tf=0.005848 cn=1 idf=1.609438
# like 3 tf=0.002924 cn=3 idf=0.510826
# leap 2 tf=0.001949 cn=0 idf=1.609438
# gatlin 2 tf=0.001949 cn=0 idf=1.609438
# about 1 tf=0.000975 cn=0 idf=1.609438
# miscount 1 tf=0.000975 cn=0 idf=1.609438
# hold 1 tf=0.000975 cn=3 idf=0.510826
# problem 1 tf=0.000975 cn=3 idf=0.510826
# fionnualla 1 tf=0.000975 cn=0 idf=1.609438
# heptathlon 2 tf=0.001949 cn=0 idf=1.609438
# trail 1 tf=0.000975 cn=1 idf=1.609438
# also 8 tf=0.007797 cn=4 idf=0.223144
# medal 5 tf=0.004873 cn=0 idf=1.609438
# lane 2 tf=0.001949 cn=0 idf=1.609438
# person 1 tf=0.000975 cn=3 idf=0.510826
# great 4 tf=0.003899 cn=1 idf=1.609438
# chief 1 tf=0.000975 cn=3 idf=0.510826
# tirunesh 1 tf=0.000975 cn=0 idf=1.609438
# kosenkow 1 tf=0.000975 cn=0 idf=1.609438
# franki 1 tf=0.000975 cn=0 idf=1.609438
# ceplak 2 tf=0.001949 cn=0 idf=1.609438
# ...
